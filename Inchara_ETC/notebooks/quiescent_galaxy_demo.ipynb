# %% [markdown]
# # Tutorial for SNR calculations for a spectrum from a file
#
# Hello! I have a file here which contains a spectrum from a quiescent galaxy. This notebook will walk you through how to parse this file and get data in photon counts, then calculate the SNR per pixel.

# %% [markdown]
# First, need to make sure you have the appropriate libraries.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append('..')

import src as src
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First, let's read in the file. You need to have a redshift for this.

# %%
z = 1.3
targ_mAB = 21
filepath = "/Users/incharajagadeesh/CASSI_26/MIRMOS/ssp_1.4Gyr_z02.spec"
wvl_arr, flux_raw, thpt, sky, atm = src.emission_spectrum_file_signal(filepath, z, targ_mAB)
